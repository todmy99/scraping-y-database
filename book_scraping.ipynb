# %% [markdown]
# ## **Scraping de la web Books To Scrape**

# %%
import requests #lo uso para hacer peticiones HTTP a la web
from bs4 import BeautifulSoup #permite parsear el HTML y extraer datos que necesitamos

url_base = "http://books.toscrape.com/"
r = requests.get(url_base) #hago la peticion, y guardo la respuesta
soup = BeautifulSoup(r.text, "html.parser") #convierte HTML a un objeto navegable

categorias = soup.select(".side_categories ul li ul li a") #permite usar selectores CSS

categorias_info = []
for cat in categorias:
    nombre = cat.text.strip() #evita espacios extra
    url = url_base + cat["href"] #arma la URL completa
    categorias_info.append({"nombre": nombre, "url": url})

categorias_info[:5]  #mostrar las primeras 5 para revisar
# Out:
# [{'nombre': 'Travel',
#   'url': 'http://books.toscrape.com/catalogue/category/books/travel_2/index.html'},
#  {'nombre': 'Mystery',
#   'url': 'http://books.toscrape.com/catalogue/category/books/mystery_3/index.html'},
#  {'nombre': 'Historical Fiction',
#   'url': 'http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html'},
#  {'nombre': 'Sequential Art',
#   'url': 'http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html'},
#  {'nombre': 'Classics',
#   'url': 'http://books.toscrape.com/catalogue/category/books/classics_6/index.html'}]

# %%
def scrapear_libros_categoria(categoria_url): #recibe el URL de cada categoria
    libros = []
    page = 1 #para revisar varias paginas dentro de la categoria
    while True: #bucle para revisar paginas
        if page == 1:
            url = categoria_url
        else:
            url = categoria_url.replace("index.html", f"page-{page}.html")
        
        r = requests.get(url)
        if r.status_code != 200: #si no devuelve codigo 200, se rompe el bucle (INVESTIGAR)
            break
        
        soup = BeautifulSoup(r.text, "html.parser") #parseo
        libros_pagina = soup.select(".product_pod") #product_pod contiene cada libro en la pagina
        if not libros_pagina:
            break #si ya no hay libros en esta categoria...
        
        for libro in libros_pagina:
            titulo = libro.h3.a["title"]
            precio = libro.select_one(".price_color").text
            rating = libro.p["class"][1]  #"One", "Two", etc.
            link_relativo = libro.h3.a["href"]
            link = url_base + "catalogue/" + link_relativo.replace("../../", "")
            
            libros.append({
                "titulo": titulo,
                "precio": precio,
                "rating": rating,
                "url": link
            })
        page += 1
    return libros

# %%
todos_los_libros = []

for cat in categorias_info:
    print("Scrapeando categoría:", cat["nombre"]) #permite ver que categoria esta scrapeando
    libros = scrapear_libros_categoria(cat["url"])
    for libro in libros:
        libro["categoria"] = cat["nombre"] #aseguramos que cada libro tenga la categoria correcta
    todos_los_libros.extend(libros) #usando extend agregamos cada elemento individualmente, append agregaria lista dentro de lista

print(f"Total de libros scrapados: {len(todos_los_libros)}")
# Out:
# Scrapeando categoría: Travel
# Scrapeando categoría: Mystery
# Scrapeando categoría: Historical Fiction
# Scrapeando categoría: Sequential Art
# Scrapeando categoría: Classics
# Scrapeando categoría: Philosophy
# Scrapeando categoría: Romance
# Scrapeando categoría: Womens Fiction
# Scrapeando categoría: Fiction
# Scrapeando categoría: Childrens
# Scrapeando categoría: Religion
# Scrapeando categoría: Nonfiction
# Scrapeando categoría: Music
# Scrapeando categoría: Default
# Scrapeando categoría: Science Fiction
# Scrapeando categoría: Sports and Games
# Scrapeando categoría: Add a comment
# Scrapeando categoría: Fantasy
# Scrapeando categoría: New Adult
# Scrapeando categoría: Young Adult
# Scrapeando categoría: Science
# Scrapeando categoría: Poetry
# Scrapeando categoría: Paranormal
# Scrapeando categoría: Art
# Scrapeando categoría: Psychology
# Scrapeando categoría: Autobiography
# Scrapeando categoría: Parenting
# Scrapeando categoría: Adult Fiction
# Scrapeando categoría: Humor
# Scrapeando categoría: Horror
# Scrapeando categoría: History
# Scrapeando categoría: Food and Drink
# Scrapeando categoría: Christian Fiction
# Scrapeando categoría: Business
# Scrapeando categoría: Biography
# Scrapeando categoría: Thriller
# Scrapeando categoría: Contemporary
# Scrapeando categoría: Spirituality
# Scrapeando categoría: Academic
# Scrapeando categoría: Self Help
# Scrapeando categoría: Historical
# Scrapeando categoría: Christian
# Scrapeando categoría: Suspense
# Scrapeando categoría: Short Stories
# Scrapeando categoría: Novels
# Scrapeando categoría: Health
# Scrapeando categoría: Politics
# Scrapeando categoría: Cultural
# Scrapeando categoría: Erotica
# Scrapeando categoría: Crime
# Total de libros scrapados: 1000

# %%
for libro in todos_los_libros:
    precio_str = libro["precio"]
    # eliminar cualquier carácter que no sea número o punto
    precio_limpio = ''.join(c for c in precio_str if c.isdigit() or c == '.')
    libro["precio"] = float(precio_limpio)

# %%
rating_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
} #convertimos string a numero entero

for libro in todos_los_libros:
    libro["rating"] = rating_map.get(libro["rating"], 0)  #0 si no se reconoce

# %%
import pandas as pd #libreria estandar de manipulacion de datos en python

df_libros = pd.DataFrame(todos_los_libros) #pd.Dataframe transforma la lista en tabla con columnas
df_libros.head(10) #mostramos las primeras 10 filas
# Out:
#                                               titulo  precio  rating  \
# 0                            It's Only the Himalayas   45.17       2
# 1  Full Moon over Noahâs Ark: An Odyssey to Mou...   49.43       4
# 2  See America: A Celebration of Our National Par...   48.87       3
# 3  Vagabonding: An Uncommon Guide to the Art of L...   36.94       2
# 4                               Under the Tuscan Sun   37.33       3
# 5                                 A Summer In Europe   44.34       2
# 6                           The Great Railway Bazaar   30.54       1
# 7                   A Year in Provence (Provence #1)   56.88       4
# 8  The Road to Little Dribbling: Adventures of an...   23.21       1
# 9          Neither Here nor There: Travels in Europe   38.95       3
#
#                                                  url categoria
# 0  http://books.toscrape.com/catalogue/../its-onl...    Travel
# 1  http://books.toscrape.com/catalogue/../full-mo...    Travel
# 2  http://books.toscrape.com/catalogue/../see-ame...    Travel
# 3  http://books.toscrape.com/catalogue/../vagabon...    Travel
# 4  http://books.toscrape.com/catalogue/../under-t...    Travel
# 5  http://books.toscrape.com/catalogue/../a-summe...    Travel
# 6  http://books.toscrape.com/catalogue/../the-gre...    Travel
# 7  http://books.toscrape.com/catalogue/../a-year-...    Travel
# 8  http://books.toscrape.com/catalogue/../the-roa...    Travel
# 9  http://books.toscrape.com/catalogue/../neither...    Travel

# %% [markdown]
# ## **Utilizamos la API Google Books para encontrar autores**

# %%
import os
from dotenv import load_dotenv
load_dotenv()

API_KEY = os.getenv("GOOGLE_BOOKS_API_KEY") #evita poner la clave directamente en el codigo

# %%
import requests #solicitudes HTTP a la api
import time #para las pausas entre solicitudes

def buscar_autores_google(titulo):
    query = f"https://www.googleapis.com/books/v1/volumes?q={titulo}&key={API_KEY}"
    r = requests.get(query)
    if r.status_code == 200:
        data = r.json() #convierte el JSON en un diccionario python
        if "items" in data and len(data["items"]) > 0:
            # tomar el primer resultado
            autores = data["items"][0]["volumeInfo"].get("authors", ["Desconocido"])
            return autores
    return ["Desconocido"] #si no encuentra nada o hay error, devuelve desconocido

# %%
autores_list = []

for i, libro in enumerate(todos_los_libros):
    titulo = libro["titulo"]
    autores = buscar_autores_google(titulo) #llama a la funcion definida
    autores_list.append(autores)
    
    # imprimir progreso
    print(f"{i+1}/{len(todos_los_libros)}: {titulo} → {autores}")
    
    # esperar 1 segundo entre requests
    time.sleep(1)
# Out:
# 1/1000: It's Only the Himalayas → ['Desconocido']
# 2/1000: Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond → ['Desconocido']
# 3/1000: See America: A Celebration of Our National Parks & Treasured Sites → ['Desconocido']
# 4/1000: Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel → ['Desconocido']
# 5/1000: Under the Tuscan Sun → ['Desconocido']
# 6/1000: A Summer In Europe → ['Desconocido']
# 7/1000: The Great Railway Bazaar → ['Desconocido']
# 8/1000: A Year in Provence (Provence #1) → ['Peter Mayle']
# 9/1000: The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2) → ['Bill Bryson']
# 10/1000: Neither Here nor There: Travels in Europe → ['Desconocido']
# 11/1000: 1,000 Places to See Before You Die → ['Desconocido']
# 12/1000: Sharp Objects → ['Desconocido']
# 13/1000: In a Dark, Dark Wood → ['Desconocido']
# 14/1000: The Past Never Ends → ['Desconocido']
# 15/1000: A Murder in Time → ['Desconocido']
# 16/1000: The Murder of Roger Ackroyd (Hercule Poirot #4) → ['Agatha Christie']
# 17/1000: The Last Mile (Amos Decker #2) → ['Trivion Books']
# 18/1000: That Darkness (Gardiner and Renner #1) → ['Lisa Black']
# 19/1000: Tastes Like Fear (DI Marnie Rome #3) → ['Sarah Hilary']
# 20/1000: A Time of Torment (Charlie Parker #14) → ['John Connolly']
# 21/1000: A Study in Scarlet (Sherlock Holmes #1) → ['Arthur Conan Doyle, Sir']
# 22/1000: Poisonous (Max Revere Novels #3) → ['Allison Brennan']
# 23/1000: Murder at the 42nd Street Library (Raymond Ambler #1) → ['Con Lehane']
# 24/1000: Most Wanted → ['Desconocido']
# 25/1000: Hide Away (Eve Duncan #20) → ['Iris Johansen']
# 26/1000: Boar Island (Anna Pigeon #19) → ['Nevada Barr']
# 27/1000: The Widow → ['Desconocido']
# 28/1000: Playing with Fire → ['Desconocido']
# 29/1000: What Happened on Beale Street (Secrets of the South Mysteries #2) → ['Mary Ellis']
# 30/1000: The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1) → ['Rachel McMillan']
# 31/1000: Delivering the Truth (Quaker Midwife Mystery #1) → ['Edith Maxwell']
# 32/1000: The Mysterious Affair at Styles (Hercule Poirot #1) → ['Agatha Christie']
# 33/1000: In the Woods (Dublin Murder Squad #1) → ['Tana French']
# 34/1000: The Silkworm (Cormoran Strike #2) → ['Robert Galbraith']
# 35/1000: The Exiled → ['Desconocido']
# 36/1000: The Cuckoo's Calling (Cormoran Strike #1) → ['Robert Galbraith']
# 37/1000: Extreme Prey (Lucas Davenport #26) → ['John Sandford']
# 38/1000: Career of Evil (Cormoran Strike #3) → ['Robert Galbraith']
# 39/1000: The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1) → ['Alexander McCall Smith']
# 40/1000: The Girl You Lost → ['Desconocido']
# 41/1000: The Girl In The Ice (DCI Erika Foster #1) → ['Robert Bryndza']
# 42/1000: Blood Defense (Samantha Brinkman #1) → ['Marcia Clark']
# 43/1000: 1st to Die (Women's Murder Club #1) → ['James Patterson']
# 44/1000: Tipping the Velvet → ['Desconocido']
# 45/1000: Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton → ['Desconocido']
# 46/1000: A Flight of Arrows (The Pathfinders #2) → ['Lori Benton']
# 47/1000: The House by the Lake → ['Desconocido']
# 48/1000: Mrs. Houdini → ['Desconocido']
# 49/1000: The Marriage of Opposites → ['Desconocido']
# 50/1000: Glory over Everything: Beyond The Kitchen House → ['Desconocido']
# 51/1000: Love, Lies and Spies → ['Desconocido']
# 52/1000: A Paris Apartment → ['Desconocido']
# 53/1000: Lilac Girls → ['Desconocido']
# 54/1000: The Constant Princess (The Tudor Court #1) → ['Philippa Gregory']
# 55/1000: The Invention of Wings → ['Desconocido']
# 56/1000: World Without End (The Pillars of the Earth #2) → ['Ken Follett']
# 57/1000: The Passion of Dolssa → ['Desconocido']
# 58/1000: Girl With a Pearl Earring → ['Desconocido']
# 59/1000: Voyager (Outlander #3) → ['Diana Gabaldon']
# 60/1000: The Red Tent → ['Desconocido']
# 61/1000: The Last Painting of Sara de Vos → ['Desconocido']
# 62/1000: The Guernsey Literary and Potato Peel Pie Society → ['Desconocido']
# 63/1000: Girl in the Blue Coat → ['Desconocido']
# 64/1000: Between Shades of Gray → ['Desconocido']
# 65/1000: While You Were Mine → ['Desconocido']
# 66/1000: The Secret Healer → ['Desconocido']
# 67/1000: Starlark → ['Desconocido']
# 68/1000: Lost Among the Living → ['Desconocido']
# 69/1000: A Spy's Devotion (The Regency Spies of London #1) → ['Melanie Dickerson']
# 70/1000: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) → ["Bryan Lee O'Malley"]
# 71/1000: Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2) → ['CLAMP']
# 72/1000: This One Summer → ['Desconocido']
# 73/1000: The Nameless City (The Nameless City #1) → ['Faith Erin Hicks']
# 74/1000: Saga, Volume 5 (Saga (Collected Editions) #5) → ['Stan Sakai']
# 75/1000: Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15) → ['Michael Pawuk', 'David S. Serchay']
# 76/1000: Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1) → ['Akiko Higashimura']
# 77/1000: Pop Gun War, Volume 1: Gift → ['Desconocido']
# 78/1000: Patience → ['Desconocido']
# 79/1000: Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1) → ['Robert Kirkman']
# 80/1000: orange: The Complete Collection 1 (orange: The Complete Collection #1) → ['Ichigo Takano']
# 81/1000: Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8) → ['Shannon Watters', 'Grace Ellis', 'ND Stevenson']
# 82/1000: Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4) → ['Shannon Watters', 'ND Stevenson', 'Gus Allen', 'Grace Ellis']
# 83/1000: Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12) → ['Shannon Watters', 'ND Stevenson', 'Gus Allen', 'Grace Ellis']
# 84/1000: I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5) → ['Skottie Young']
# 85/1000: I am a Hero Omnibus Volume 1 → ['Desconocido']
# 86/1000: Giant Days, Vol. 2 (Giant Days #5-8) → ['John Allison']
# 87/1000: Danganronpa Volume 1 → ['Desconocido']
# 88/1000: Codename Baboushka, Volume 1: The Conclave of Death → ['Desconocido']
# 89/1000: Camp Midnight → ['Desconocido']
# 90/1000: Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions)) → ['Desconocido']
# 91/1000: The Shadow Hero (The Shadow Hero) → ['Desconocido']
# 92/1000: Fables, Vol. 1: Legends in Exile (Fables #1) → ['Bill Willingham']
# 93/1000: Batman: The Long Halloween (Batman) → ['Desconocido']
# 94/1000: Batman: The Dark Knight Returns (Batman) → ['Desconocido']
# 95/1000: Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1) → ['Grant Morrison']
# 96/1000: We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1) → ['Lee Bermejo']
# 97/1000: Through the Woods → ['Desconocido']
# 98/1000: Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1) → ['Gene Luen Yang']
# 99/1000: So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6) → ['Migiri Miki']
# 100/1000: Robin War → ['Desconocido']
# 101/1000: Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1) → ['Scott Lobdell']
# 102/1000: Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14) → ['Masashi Kishimoto']
# 103/1000: Lowriders to the Center of the Earth (Lowriders in Space #2) → ['Cathy Camper']
# 104/1000: El Deafo → ['Desconocido']
# 105/1000: Batman: Europa → ['Desconocido']
# 106/1000: Art Ops Vol. 1 → ['Desconocido']
# 107/1000: Adulthood Is a Myth: A "Sarah's Scribbles" Collection → ['Desconocido']
# 108/1000: Fruits Basket, Vol. 9 (Fruits Basket #9) → ['David Armstrong', 'Roberto J. De La Noval']
# 109/1000: Roller Girl → ['Desconocido']
# 110/1000: Fruits Basket, Vol. 7 (Fruits Basket #7) → ['Natsuki Takaya']
# 111/1000: Fruits Basket, Vol. 6 (Fruits Basket #6) → ['Alice M. LeGrow']
# 112/1000: Death Note, Vol. 6: Give-and-Take (Death Note #6) → ['Tsugumi Ohba']
# 113/1000: Fruits Basket, Vol. 5 (Fruits Basket #5) → ['Natsuki Takaya']
# 114/1000: Death Note, Vol. 5: Whiteout (Death Note #5) → ['Tsugumi Ōba']
# 115/1000: The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4) → ['Aya Shouoto']
# 116/1000: Fruits Basket, Vol. 4 (Fruits Basket #4) → ['Natsuki Takaya']
# 117/1000: The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine) → ['Desconocido']
# 118/1000: The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3) → ['Neil Gaiman']
# 119/1000: Saga, Volume 3 (Saga (Collected Editions) #3) → ['Stan Sakai']
# 120/1000: Prodigy: The Graphic Novel (Legend: The Graphic Novel #2) → ['Marie Lu']
# 121/1000: Persepolis: The Story of a Childhood (Persepolis #1-2) → ['Marjane Satrapi']
# 122/1000: Original Fake → ['Desconocido']
# 123/1000: Grayson, Vol 3: Nemesis (Grayson #3) → ['Tim Seeley', 'Tom King']
# 124/1000: Fruits Basket, Vol. 3 (Fruits Basket #3) → ['Natsuki Takaya']
# 125/1000: Black Butler, Vol. 1 (Black Butler #1) → ['Yana Toboso']
# 126/1000: Awkward → ['Desconocido']
# 127/1000: The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2) → ['Neil Gaiman', 'Various']
# 128/1000: Saga, Volume 2 (Saga (Collected Editions) #2) → ['John Jackson Miller', 'Paul S. Kemp', 'Alexander Freed', 'Jason Fry', 'Timothy Zahn', 'Christie Golden', 'Jennifer Heddle', 'Joe Schreiber', 'Edward M. Erdelac', 'James S. A. Corey', 'Michael Kogge', 'Janine K. Spendlove', 'Sylvain Neuvel', 'Delilah S. Dawson', 'Jason M. Hough', 'Mur Lafferty']
# 129/1000: Fruits Basket, Vol. 2 (Fruits Basket #2) → ['David Armstrong', 'Roberto J. De La Noval']
# 130/1000: Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1) → ['Jess Nevins']
# 131/1000: The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine) → ['Desconocido']
# 132/1000: The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1) → ['Neil Gaiman']
# 133/1000: The Complete Maus (Maus #1-2) → ['Art Spiegelman']
# 134/1000: Skip Beat!, Vol. 01 (Skip Beat! #1) → ['Michael Pawuk', 'David S. Serchay']
# 135/1000: Saga, Volume 1 (Saga (Collected Editions) #1) → ['Stan Sakai']
# 136/1000: Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5) → ['Kurtis J Wiebe']
# 137/1000: Paper Girls, Vol. 1 (Paper Girls #1-5) → ['Brian K. Vaughan']
# 138/1000: Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1) → ['Bisco Hatori']
# 139/1000: Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1) → ['G. Willow Wilson']
# 140/1000: Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1) → ['Matt Fraction']
# 141/1000: Giant Days, Vol. 1 (Giant Days #1-4) → ['John Allison']
# 142/1000: Fruits Basket, Vol. 1 (Fruits Basket #1) → ['Natsuki Takaya']
# 143/1000: Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1) → ['Tite Kubo']
# 144/1000: Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1) → ['Gamon Sakurai']
# 145/1000: The Secret Garden → ['Desconocido']
# 146/1000: The Metamorphosis → ['Desconocido']
# 147/1000: The Pilgrim's Progress → ['Desconocido']
# 148/1000: The Hound of the Baskervilles (Sherlock Holmes #5) → ['A. Conan Doyle']
# 149/1000: Little Women (Little Women #1) → ['Louisa May Alcott']
# 150/1000: Gone with the Wind → ['Desconocido']
# 151/1000: Candide → ['Desconocido']
# 152/1000: Animal Farm → ['Desconocido']
# 153/1000: Wuthering Heights → ['Desconocido']
# 154/1000: The Picture of Dorian Gray → ['Desconocido']
# 155/1000: The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition]) → ['Desconocido']
# 156/1000: Beowulf → ['Desconocido']
# 157/1000: And Then There Were None → ['Desconocido']
# 158/1000: The Story of Hong Gildong → ['Desconocido']
# 159/1000: The Little Prince → ['Desconocido']
# 160/1000: Sense and Sensibility → ['Desconocido']
# 161/1000: Of Mice and Men → ['Desconocido']
# 162/1000: Emma → ['Desconocido']
# 163/1000: Alice in Wonderland (Alice's Adventures in Wonderland #1) → ['Lewis Carroll']
# 164/1000: Sophie's World → ['Desconocido']
# 165/1000: The Death of Humanity: and the Case for Life → ['Desconocido']
# 166/1000: The Stranger → ['Desconocido']
# 167/1000: Proofs of God: Classical Arguments from Tertullian to Barth → ['Desconocido']
# 168/1000: Kierkegaard: A Christian Missionary to Christians → ['Desconocido']
# 169/1000: At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others → ['Desconocido']
# 170/1000: Critique of Pure Reason → ['Desconocido']
# 171/1000: Run, Spot, Run: The Ethics of Keeping Pets → ['Desconocido']
# 172/1000: The Nicomachean Ethics → ['Desconocido']
# 173/1000: Meditations → ['Desconocido']
# 174/1000: Beyond Good and Evil → ['Desconocido']
# 175/1000: Chase Me (Paris Nights #2) → ['Laura Florand']
# 176/1000: Black Dust → ['Desconocido']
# 177/1000: Her Backup Boyfriend (The Sorensen Family #1) → ['Ashlee Mallory']
# 178/1000: First and First (Five Boroughs #3) → ['Amby Burfoot']
# 179/1000: Fifty Shades Darker (Fifty Shades #2) → ['E. L. James']
# 180/1000: The Wedding Dress → ['Desconocido']
# 181/1000: Suddenly in Love (Lake Haven #1) → ['Julia London']
# 182/1000: Something More Than This → ['Desconocido']
# 183/1000: Doing It Over (Most Likely To #1) → ['Elizabeth Krumrei Mancuso', 'Bennett E. Postlethwaite']
# 184/1000: The Wedding Pact (The O'Malleys #2) → ['Katee Robert']
# 185/1000: Hold Your Breath (Search and Rescue #1) → ['Katie Ruggle']
# 186/1000: Dirty (Dive Bar #1) → ['Kylie Scott']
# 187/1000: Take Me Home Tonight (Rock Star Romance #3) → ['Erika Kelly']
# 188/1000: Off the Hook (Fishing for Trouble #1) → ['Robert A. Slade']
# 189/1000: A Gentleman's Position (Society of Gentlemen #3) → ['KJ Charles']
# 190/1000: Sit, Stay, Love → ['Desconocido']
# 191/1000: A Girl's Guide to Moving On (New Beginnings #2) → ['Debbie Macomber']
# 192/1000: The Perfect Play (Play by Play #1) → ['William Shakespeare']
# 193/1000: Dark Lover (Black Dagger Brotherhood #1) → ['J.R. Ward']
# 194/1000: Changing the Game (Play by Play #2) → ['Eric G. Flamholtz', 'Yvonne Randle']
# 195/1000: A Walk to Remember → ['Desconocido']
# 196/1000: The Purest Hook (Second Circle Tattoos #3) → ['Scarlett Cole']
# 197/1000: The Obsession → ['Desconocido']
# 198/1000: Reservations for Two → ['Desconocido']
# 199/1000: Best of My Love (Fool's Gold #20) → ['Susan Mallery']
# 200/1000: Where Lightning Strikes (Bleeding Stars #3) → ['A. L. Jackson']
# 201/1000: This One Moment (Pushing Limits #1) → ['Stina Lindenblatt']
# 202/1000: Rhythm, Chord & Malykhin → ['Desconocido']
# 203/1000: My Perfect Mistake (Over the Top #1) → ['Carole Wolfe']
# 204/1000: Listen to Me (Fusion #1) → ['Stephen D. Rappaport']
# 205/1000: Imperfect Harmony → ['Desconocido']
# 206/1000: Fighting Fate (Fighting #6) → ['JB Salsbury']
# 207/1000: Deep Under (Walker Security #1) → ['Lisa Renee Jones']
# 208/1000: Charity's Cross (Charles Towne Belles #4) → ['MaryLu Tyndall']
# 209/1000: Bounty (Colorado Mountain #7) → ['Kristen Ashley']
# 210/1000: I Had a Nice Time And Other Lies...: How to find love & sh*t like that → ['Desconocido']
# 211/1000: Will You Won't You Want Me? → ['Desconocido']
# 212/1000: Keep Me Posted → ['Desconocido']
# 213/1000: Grey (Fifty Shades #4) → ['E. L. James']
# 264/1000: Sister Dear → ['Desconocido']
# 265/1000: Memoirs of a Geisha → ['Desconocido']
# 266/1000: Me Before You (Me Before You #1) → ['Johann Wolfgang von Goethe', 'Stendhal', 'Jules Verne', 'Gustave Flaubert', 'Theodor Storm', 'Henrik Ibsen', 'Charles Dickens', 'Honoré de Balzac', 'Harriet Beecher Stowe', 'Rabindranath Tagore', 'Fyodor Dostoyevsky', 'James Fenimore Cooper', 'Edgar Allan Poe', 'John Buchan', 'Confucius,', 'George MacDonald', 'Bram Stoker', 'Henry James', 'Victor Hugo', 'Joseph Conrad', 'Jane Austen', 'Walter Scott', 'Laurence Sterne', 'Thomas Hardy', 'Jonathan Swift', 'Edith Wharton', 'Benito Pérez Galdós', 'Daniel Defoe', 'Henry Fielding', 'Sinclair Lewis', 'Anthony Trollope', 'Alexandre Dumas', 'William Dean Howells', 'Virginia Woolf', 'William Walker Atkinson', 'Kenneth Grahame', 'Washington Irving', 'Willa Cather', 'Nathaniel Hawthorne', 'Homer', 'Gaston Leroux', 'Ford Madox Ford', 'Benjamin Franklin', 'Kate Chopin', 'John Milton', 'Edgar Wallace', 'Laozi', 'James Joyce', 'Ann Ward Radcliffe', 'Kakuzo Okakura', 'H. G. Wells', 'W. B. Yeats', 'J. M. Barrie', 'G. K. Chesterton', 'Jerome K. Jerome', 'L. M. Montgomery', 'W. Somerset Maugham', 'E. M. Forster', 'F. Scott Fitzgerald', 'Lewis Wallace', 'Ivan Turgenev', 'Leo Tolstoy', 'Nikolai Gogol', 'George Bernard Shaw', 'Cao Xueqin', 'Emile Zola', 'Bankim Chandra Chatterjee', 'P. B. Shelley', 'Elizabeth von Arnim', 'Dante', 'Pedro Calderon de la Barca', 'Émile Coué', 'George Weedon Grossmith', 'Willkie Collins', 'D.H. Lawrence', 'Machiavelli']
# 267/1000: Deception Point → ['Desconocido']
# 268/1000: The Little Paris Bookshop → ['Desconocido']
# 269/1000: The Firm → ['Desconocido']
# 270/1000: The Expatriates → ['Desconocido']
# 271/1000: Siddhartha → ['Desconocido']
# 272/1000: Last One Home (New Beginnings #1) → ['Debbie Macomber']
# 273/1000: Digital Fortress → ['Desconocido']
# 274/1000: Atlas Shrugged → ['Desconocido']
# 275/1000: Three-Martini Lunch → ['Desconocido']
# 276/1000: The Nightingale → ['Desconocido']
# 277/1000: The Infinities → ['Desconocido']
# 278/1000: The Husband's Secret → ['Desconocido']
# 279/1000: The Da Vinci Code (Robert Langdon #2) → ['Dan Brown']
# 280/1000: The Art of Fielding → ['Desconocido']
# 281/1000: Lila (Gilead #3) → ['Timothy Larsen', 'Keith L. Johnson']
# 282/1000: Jurassic Park (Jurassic Park #1) → ['Desconocido']
# 283/1000: Inferno (Robert Langdon #4) → ['Dan Brown']
# 284/1000: Crazy Rich Asians (Crazy Rich Asians #1) → ['Kevin Kwan']
# 285/1000: Big Little Lies → ['Desconocido']
# 286/1000: The Course of Love → ['Desconocido']
# 287/1000: When I'm Gone → ['Desconocido']
# 582/1000: Life After Life → ['Desconocido']
# 583/1000: Lean In: Women, Work, and the Will to Lead → ['Desconocido']
# 584/1000: Is Everyone Hanging Out Without Me? (And Other Concerns) → ['Desconocido']
# 585/1000: Gone Girl → ['Desconocido']
# 586/1000: Fellside → ['Desconocido']
# 587/1000: Eclipse (Twilight #3) → ['Sam M. Silverman', 'E. G. Mullen', 'Edward G. Mullen']
# 588/1000: Dracula → ['Desconocido']
# 589/1000: Dead Wake: The Last Crossing of the Lusitania → ['Desconocido']
# 590/1000: David and Goliath: Underdogs, Misfits, and the Art of Battling Giants → ['Desconocido']
# 591/1000: Dark Places → ['Desconocido']
# 592/1000: Breaking Dawn (Twilight #4) → ['Stephenie Meyer']
# 593/1000: Beautiful Creatures (Caster Chronicles #1) → ['Kami Garcia', 'Margaret Stohl']
# 594/1000: A Visit from the Goon Squad → ['Desconocido']
# 595/1000: The Zombie Room → ['Desconocido']
# 596/1000: The Name of the Wind (The Kingkiller Chronicle #1) → ['Patrick Rothfuss']
# 597/1000: Taking Shots (Assassins #1) → ['Toni Aleo']
# 598/1000: Shatter Me (Shatter Me #1) → ['Tahereh Mafi']
# 599/1000: Paradise Lost (Paradise #1) → ['John Milton']
# 600/1000: On the Road (Duluoz Legend) → ['Desconocido']
# 601/1000: Jane Eyre → ['Desconocido']
# 602/1000: Frankenstein → ['Desconocido']
# 603/1000: Mesaerion: The Best Science Fiction Stories 1800-1849 → ['Desconocido']
# 604/1000: Join → ['Desconocido']
# 605/1000: William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4) → ['Ian Doescher']
# 606/1000: The Project → ['Desconocido']
# 607/1000: Soft Apocalypse → ['Desconocido']
# 608/1000: Sleeping Giants (Themis Files #1) → ['Sylvain Neuvel']
# 609/1000: Arena → ['Desconocido']
# 610/1000: Foundation (Foundation (Publication Order) #1) → ['United States. Superintendent of Documents']
# 611/1000: The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2) → ['Douglas Adams']
# 612/1000: Ready Player One → ['Desconocido']
# 613/1000: Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3) → ['Douglas Adams']
# 614/1000: Dune (Dune #1) → ['Kara Kennedy']
# 615/1000: Do Androids Dream of Electric Sheep? (Blade Runner #1) → ['Judith Kerman']
# 616/1000: Three Wishes (River of Time: California #1) → ['Lisa T. Bergren']
# 617/1000: The Last Girl (The Dominion Trilogy #1) → ['Robin Parrish']
# 618/1000: Having the Barbarian's Baby (Ice Planet Barbarians #7.5) → ['Ruby Dixon']
# 619/1000: The Book of Basketball: The NBA According to The Sports Guy → ['Desconocido']
# 620/1000: Friday Night Lights: A Town, a Team, and a Dream → ['Desconocido']
# 621/1000: Sugar Rush (Offensive Line #2) → ['Phil Nuernberger']
# 622/1000: Settling the Score (The Summer Games #1) → ['R. S. Grey']
# 623/1000: Icing (Aces Hockey #2) → ['Kelly Jamieson']
# 624/1000: The Torch Is Passed: A Harding Family Story → ['Desconocido']
# 625/1000: The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy → ['Desconocido']
# 626/1000: The Art Forger → ['Desconocido']
# 627/1000: On a Midnight Clear → ['Desconocido']
# 628/1000: Judo: Seven Steps to Black Belt (an Introductory Guide for Begin
-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days! → ['Desconocido']
# 994/1000: The Art and Science of Low Carbohydrate Living → ['Desconocido']
# 995/1000: Libertarianism for Beginners → ['Desconocido']
# 996/1000: Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond → ['Desconocido']
# 997/1000: Equal Is Unfair: America's Misguided Fight Against Income Inequality → ['Desconocido']
# 998/1000: Amid the Chaos → ['Desconocido']
# 999/1000: Dark Notes → ['Desconocido']
# 1000/1000: The Long Shadow of Small Ghosts: Murder and Memory in an American City → ['Desconocido']

# %%
import pandas as pd
#convierte la lista de todos los libros en tablas panda
df_libros = pd.DataFrame(todos_los_libros)
df_libros["autores"] = autores_list #agrego nueva columna

df_libros.head(10) #compruebo con los primeros 10
# Out:
#                                               titulo  precio  rating  \
# 0                            It's Only the Himalayas   45.17       2
# 1  Full Moon over Noahâs Ark: An Odyssey to Mou...   49.43       4
# 2  See America: A Celebration of Our National Par...   48.87       3
# 3  Vagabonding: An Uncommon Guide to the Art of L...   36.94       2
# 4                               Under the Tuscan Sun   37.33       3
# 5                                 A Summer In Europe   44.34       2
# 6                           The Great Railway Bazaar   30.54       1
# 7                   A Year in Provence (Provence #1)   56.88       4
# 8  The Road to Little Dribbling: Adventures of an...   23.21       1
# 9          Neither Here nor There: Travels in Europe   38.95       3
#
#                                                  url categoria        autores
# 0  http://books.toscrape.com/catalogue/../its-onl...    Travel  [Desconocido]
# 1  http://books.toscrape.com/catalogue/../full-mo...    Travel  [Desconocido]
# 2  http://books.toscrape.com/catalogue/../see-ame...    Travel  [Desconocido]
# 3  http://books.toscrape.com/catalogue/../vagabon...    Travel  [Desconocido]
# 4  http://books.toscrape.com/catalogue/../under-t...    Travel  [Desconocido]
# 5  http://books.toscrape.com/catalogue/../a-summe...    Travel  [Desconocido]
# 6  http://books.toscrape.com/catalogue/../the-gre...    Travel  [Desconocido]
# 7  http://books.toscrape.com/catalogue/../a-year-...    Travel  [Peter Mayle]
# 8  http://books.toscrape.com/catalogue/../the-roa...    Travel  [Bill Bryson]
# 9  http://books.toscrape.com/catalogue/../neither...    Travel  [Desconocido]

# %% [markdown]
# ## **Creamos la base de datos en donde almacenar todos los libros y autores**

# %%
import sqlite3

# Conexión a SQLite (crea el archivo si no existe)
conn = sqlite3.connect("books.db")
cursor = conn.cursor() #cursor = objeto que permite ejecutar comandos en SQL

# Tabla Libros
cursor.execute("""
CREATE TABLE IF NOT EXISTS Libros (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    titulo TEXT,
    precio REAL,
    rating INTEGER,
    url TEXT,
    categoria TEXT
)
""")

# Tabla Autores
cursor.execute("""
CREATE TABLE IF NOT EXISTS Autores (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nombre TEXT UNIQUE
)
""")

# Tabla intermedia Libros_Autores
cursor.execute("""
CREATE TABLE IF NOT EXISTS Libros_Autores (
    libro_id INTEGER,
    autor_id INTEGER,
    FOREIGN KEY(libro_id) REFERENCES Libros(id),
    FOREIGN KEY(autor_id) REFERENCES Autores(id)
)
""") #asocia libro y autor, ambos deben existir

conn.commit()

# %%
for _, row in df_libros.iterrows(): #cargamos los datos en la tabla libros uno por uno
    cursor.execute("""
    INSERT INTO Libros (titulo, precio, rating, url, categoria)
    VALUES (?, ?, ?, ?, ?)
    """, (row['titulo'], row['precio'], row['rating'], row['url'], row['categoria']))

conn.commit()

# %%
for autores in df_libros['autores']: #de la lista de autores, se inserta a cada uno por separado
    for autor in autores:
        cursor.execute("""
        INSERT OR IGNORE INTO Autores (nombre) VALUES (?)
        """, (autor,))
        
conn.commit()

# %%
for _, row in df_libros.iterrows(): #iterrows = acceder fila por fila al dataframe
    # obtener id del libro
    cursor.execute("SELECT id FROM Libros WHERE titulo = ?", (row['titulo'],)) #obtiene el id de cada libro
    libro_id = cursor.fetchone()[0]
    
    for autor in row['autores']: #recorremos cada autor del libro y buscamos su id
        cursor.execute("SELECT id FROM Autores WHERE nombre = ?", (autor,))
        autor_id = cursor.fetchone()[0]
        
        # insertar en tabla intermedia
        cursor.execute("""
        INSERT INTO Libros_Autores (libro_id, autor_id) VALUES (?, ?)
        """, (libro_id, autor_id))

conn.commit()

# %% [markdown]
# ## **Diagrama UML de la Base de Datos**
#
# El siguiente diagrama muestra las tablas y sus relaciones:
#
# ![](UMLdatabase.png)

# %% [markdown]
# ## **Consultas varias**

# %% [markdown]
# #### **Consulta 1: Libros con puntuacion de 4 estrellas o mas**

# %%
query1 = """
SELECT titulo, precio
FROM Libros
WHERE rating >= 4;
"""
cursor.execute(query1)
cursor.fetchall()
# Out:
# [('Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   49.43),
#  ('A Year in Provence (Provence #1)', 56.88),
#  ('1,000 Places to See Before You Die', 26.08),
#  ('Sharp Objects', 47.82),
#  ('The Past Never Ends', 56.5),
#  ('The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1),
#  ('A Time of Torment (Charlie Parker #14)', 48.35),
#  ('Murder at the 42nd Street Library (Raymond Ambler #1)', 54.36),
#  ('What Happened on Beale Street (Secrets of the South Mysteries #2)', 25.37),
#  ("The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   52.3),
#  ('Delivering the Truth (Quaker Midwife Mystery #1)', 20.89),
#  ('The Mysterious Affair at Styles (Hercule Poirot #1)', 24.8),
#  ('The Silkworm (Cormoran Strike #2)', 23.05),
#  ("The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#   57.7),
#  ('The Girl You Lost', 12.29),
#  ('A Flight of Arrows (The Pathfinders #2)', 55.53),
#  ('Mrs. Houdini', 30.25),
#  ('The Marriage of Opposites', 28.08),
#  ('A Paris Apartment', 39.01),
#  ('World Without End (The Pillars of the Earth #2)', 32.97),
#  ('The Passion of Dolssa', 28.32),
#  ('Voyager (Outlander #3)', 21.07),
#  ('The Red Tent', 35.66),
#  ('Between Shades of Gray', 20.79),
#  ('While You Were Mine', 41.32),
#  ('Lost Among the Living', 27.7),
#  ("A Spy's Devotion (The Regency Spies of London #1)", 16.97),
#  ("Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 52.29),
#  ('This One Summer', 19.49),
#  ('The Nameless City (The Nameless City #1)', 38.16),
#  ('Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   13.61),
#  ('Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 15.44),
#  ('Danganronpa Volume 1', 51.99),
#  ('Codename Baboushka, Volume 1: The Conclave of Death', 36.72),
#  ('Camp Midnight', 17.08),
#  ('Fables, Vol. 1: Legends in Exile (Fables #1)', 41.62),
#  ('Batman: The Dark Knight Returns (Batman)', 15.38),
#  ('Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', 37.34),
#  ('Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 11.89),
#  ('So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)', 35.43),
#  ('El Deafo', 57.62),
#  ('Fruits Basket, Vol. 9 (Fruits Basket #9)', 33.95),
#  ('Roller Girl', 14.1),
#  ('Fruits Basket, Vol. 6 (Fruits Basket #6)', 20.96),
#  ('Fruits Basket, Vol. 4 (Fruits Basket #4)', 50.44),
#  ('The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)', 55.55),
#  ('Saga, Volume 3 (Saga (Collected Editions) #3)', 21.57),
#  ('Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64),
#  ('Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', 18.51),
#  ('Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   46.96),
#  ('Paper Girls, Vol. 1 (Paper Girls #1-5)', 21.71),
#  ('Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', 39.39),
#  ('Giant Days, Vol. 1 (Giant Days #1-4)', 56.76),
#  ('Fruits Basket, Vol. 1 (Fruits Basket #1)', 40.28),
#  ('Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', 34.65),
#  ('Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', 57.06),
#  ('The Secret Garden', 15.08),
#  ('Little Women (Little Women #1)', 28.07),
#  ('The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#   26.78),
#  ('The Story of Hong Gildong', 43.19),
#  ("Sophie's World", 15.94),
#  ('The Death of Humanity: and the Case for Life', 58.11),
#  ('The Stranger', 17.44),
#  ('At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#   29.93),
#  ('Chase Me (Paris Nights #2)', 25.27),
#  ('Black Dust', 34.53),
#  ('First and First (Five Boroughs #3)', 15.97),
#  ('Something More Than This', 16.24),
#  ('Dirty (Dive Bar #1)', 40.83),
#  ("A Gentleman's Position (Society of Gentlemen #3)", 14.75),
#  ('Imperfect Harmony', 34.74),
#  ('Deep Under (Walker Security #1)', 47.09),
#  ('Bounty (Colorado Mountain #7)', 37.26),
#  ('I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   57.36),
#  ('Keep Me Posted', 20.46),
#  ('Grey (Fifty Shades #4)', 48.49),
#  ('Some Women', 13.73),
#  ('Shopaholic Ties the Knot (Shopaholic #3)', 48.39),
#  ('The Undomestic Goddess', 45.75),
#  ('The Nanny Diaries (Nanny #1)', 52.53),
#  ('Something Borrowed (Darcy & Rachel #1)', 48.96),
#  ('The Edge of Reason (Bridget Jones #2)', 19.18),
#  ('Private Paris (Private #10)', 47.61),
#  ('We Love You, Charlie Freeman', 50.27),
#  ('Thirst', 17.27),
#  ('The Vacationers', 42.15),
#  ('The Regional Office Is Under Attack!', 51.36),
#  ('Finders Keepers (Bill Hodges Trilogy #2)', 53.53),
#  ('The Time Keeper', 27.88),
#  ('The Testament of Mary', 52.67),
#  ('Shtum', 55.84),
#  ('I Am Pilgrim (Pilgrim #1)', 10.6),
#  ('Eight Hundred Grapes', 14.39),
#  ('Dear Mr. Knightley', 11.21),
#  ('The Silent Sister (Riley MacPherson #1)', 46.29),
#  ('Hystopia: A Novel', 21.96),
#  ('The Bourne Identity (Jason Bourne #1)', 42.78),
#  ('Sister Dear', 40.2),
#  ('Deception Point', 40.32),
#  ('Siddhartha', 34.22),
#  ('Digital Fortress', 58.0),
#  ('Atlas Shrugged', 26.58),
#  ('The Nightingale', 26.26),
#  ("The Husband's Secret", 52.51),
#  ('Inferno (Robert Langdon #4)', 41.0),
#  ('Crazy Rich Asians (Crazy Rich Asians #1)', 49.13),
#  ('The Silent Wife', 12.34),
#  ('Kitchens of the Great Midwest', 57.2),
#  ('Bright Lines', 39.07),
#  ('The White Cat and the Monk: A Retelling of the Poem â\x80\x9cPangur BÃ¡nâ\x80\x9d',
#   58.08),
#  ("Walt Disney's Alice in Wonderland", 12.96),
#  ('The Whale', 35.96),
#  ('The Lonely Ones', 43.59),
#  ('The Day the Crayons Came Home (Crayons)', 26.33),
#  ('Green Eggs and Ham (Beginner Books B-16)', 10.79),
#  ('Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#   52.88),
#  ('You Are What You Love: The Spiritual Power of Habit', 21.87),
#  ('God: The Most Unpleasant Character in All Fiction', 30.03),
#  ("Choosing Our Religion: The Spiritual Lives of America's Nones", 28.42),
#  ('Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe', 40.3),
#  ('#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 23.11),
#  ('Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   44.18),
#  ('Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   41.83),
#  ('In the Country We Love: My Family Divided', 22.0),
#  ('Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 29.14),
#  ("The Artist's Way: A Spiritual Path to Higher Creativity", 38.49),
#  ('Agnostic: A Spirited Manifesto', 12.51),
#  ('Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   38.2),
#  ('Looking for Lovely: Collecting the Moments that Matter', 29.14),
#  ('Let It Out: A Journey Through Journaling', 26.79),
#  ('Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   15.06),
#  ('Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#   51.75),
#  ('Buying In: The Secret Dialogue Between What We Buy and Who We Are', 37.8),
#  ('Brain on Fire: My Month of Madness', 49.32),
#  ('Abstract City', 56.37),
#  ('Furiously Happy: A Funny Book About Horrible Things', 41.46),
#  ('The Sleep Revolution: Transforming Your Life, One Night at a Time', 11.68),
#  ('Mother, Can You Not?', 16.89),
#  ("The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#   28.45),
#  ('Smarter Faster Better: The Secrets of Being Productive in Life and Business',
#   38.89),
#  ('Between the World and Me', 56.91),
#  ('Being Mortal: Medicine and What Matters in the End', 55.06),
#  ('The Man Who Mistook His Wife for a Hat and Other Clinical Tales', 59.45),
#  ('In Cold Blood', 49.98),
#  ("Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",
#   25.15),
#  ('My Mother Was Nuts', 31.63),
#  ('The Gunning of America: Business and the Making of American Gun Culture',
#   16.81),
#  ('Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',
#   41.67),
#  ('Into the Wild', 56.7),
#  ('Gratitude', 26.66),
#  ('Disrupted: My Misadventure in the Start-Up Bubble', 15.28),
#  ('Brave Enough', 51.32),
#  ('Blink: The Power of Thinking Without Thinking', 21.74),
#  ('A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#   30.48),
#  ('H is for Hawk', 57.42),
#  ('Travels with Charley: In Search of America', 57.82),
#  ('The Tumor', 41.56),
#  ('Rip it Up and Start Again', 35.02),
#  ('Please Kill Me: The Uncensored Oral History of Punk', 31.19),
#  ("Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   45.05),
#  ('No One Here Gets Out Alive', 20.02),
#  ('Life', 31.58),
#  ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   22.6),
#  ('The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   20.59),
#  ('A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 56.76),
#  ('The Secret (The Secret #1)', 27.37),
#  ('The Kite Runner', 41.82),
#  ('The Art of War', 33.34),
#  ('Eureka Trivia 6.0', 54.59),
#  ('Drive: The Surprising Truth About What Motivates Us', 34.95),
#  ('Done Rubbed Out (Reightman & Bailey #1)', 37.72),
#  ('Anonymous', 46.82),
#  ('Amatus', 50.54),
#  ('V for Vendetta (V for Vendetta Complete)', 37.1),
#  ('The Wright Brothers', 56.8),
#  ('The Songs of the Gods', 44.48),
#  ('Steve Jobs', 39.5),
#  ('Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#   46.91),
#  ('Lady Midnight (The Dark Artifices #1)', 16.28),
#  ('Greek Mythic History', 10.23),
#  ('City of Fallen Angels (The Mortal Instruments #4)', 11.23),
#  ('Raspberry Pi Electronics Projects for the Evil Genius', 49.67),
#  ('How to Speak Golf: An Illustrated Guide to Links Lingo', 58.32),
#  ('Eleanor & Park', 56.51),
#  ('Adultery', 20.88),
#  ('Unlimited Intuition Now', 58.87),
#  ('The New Brand You: Your New Image Makes the Sale for You', 44.05),
#  ('NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   10.41),
#  ('The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', 43.62),
#  ('John Vassos: Industrial Design for Modern Life', 20.22),
#  ('Death by Leisure: A Cautionary Tale', 37.51),
#  ('The Great Gatsby', 36.05),
#  ('The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#   33.17),
#  ('Life of Pi', 13.22),
#  ('The Sound Of Love', 57.84),
#  ('The Hobbit (Middle-Earth Universe)', 17.8),
#  ('What If?: Serious Scientific Answers to Absurd Hypothetical Questions',
#   53.68),
#  ('Shiver (The Wolves of Mercy Falls #1)', 16.23),
#  ('If I Stay (If I Stay #1)', 38.13),
#  ('Blue Lily, Lily Blue (The Raven Cycle #3)', 34.13),
#  ('Alight (The Generations Trilogy #2)', 58.59),
#  ('Vogue Colors A to Z: A Fashion Coloring Book', 52.35),
#  ('The Hunger Games (The Hunger Games #1)', 29.85),
#  ('Outlander (Outlander #1)', 19.67),
#  ('Mockingjay (The Hunger Games #3)', 20.44),
#  ('The Demon-Haunted World: Science as a Candle in the Dark', 52.25),
#  ('Gone Girl', 37.6),
#  ('Dead Wake: The Last Crossing of the Lusitania', 39.24),
#  ('Dark Places', 23.9),
#  ('Breaking Dawn (Twilight #4)', 35.28),
#  ('Beautiful Creatures (Caster Chronicles #1)', 21.55),
#  ('A Visit from the Goon Squad', 14.08),
#  ('The Zombie Room', 19.69),
#  ('Jane Eyre', 38.43),
#  ('Join', 35.67),
#  ("William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#   43.3),
#  ('Arena', 21.36),
#  ('Ready Player One', 19.07),
#  ("Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", 34.96),
#  ('The Book of Basketball: The NBA According to The Sports Guy', 44.84),
#  ('Icing (Aces Hockey #2)', 40.44),
#  ('The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   23.89),
#  ('Modern Romance', 28.26),
#  ("The White Queen (The Cousins' War #1)", 25.91),
#  ('The Song of Achilles', 37.4),
#  ('Code Name Verity (Code Name Verity #1)', 22.13),
#  ('Cell', 20.29),
#  ('Rook', 37.86),
#  ('The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   59.15),
#  ('One with You (Crossfire #5)', 15.71),
#  ('Without Shame', 48.27),
#  ('Watchmen', 58.05),
#  ('Team of Rivals: The Political Genius of Abraham Lincoln', 20.12),
#  ('John Adams', 57.43),
#  ('Good in Bed (Cannie Shapiro #1)', 37.05),
#  ('The Joy of Cooking', 43.27),
#  ('Pride and Prejudice', 19.27),
#  ('Fun Home: A Family Tragicomic', 56.59),
#  ('The End of Faith: Religion, Terror, and the Future of Reason', 22.13),
#  ('The Complete Poems', 41.32),
#  ('The Blind Side: Evolution of a Game', 53.71),
#  ('Fire Bound (Sea Haven/Sisters of the Heart #5)', 21.28),
#  ('Princess Between Worlds (Wide-Awake Princess #5)', 13.34),
#  ('The Star-Touched Queen', 46.02),
#  ('The Bane Chronicles (The Bane Chronicles #1-11)', 44.73),
#  ('Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#   37.51),
#  ('City of Glass (The Mortal Instruments #3)', 56.02),
#  ('The Star-Touched Queen', 32.3),
#  ("King's Folly (The Kinsman Chronicles #1)", 39.61),
#  ('Every Heart a Doorway (Every Heart A Doorway #1)', 12.16),
#  ('A Gathering of Shadows (Shades of Magic #2)', 44.81),
#  ('The Raven Boys (The Raven Cycle #1)', 57.74),
#  ('The False Prince (The Ascendance Trilogy #1)', 56.0),
#  ('A Feast for Crows (A Song of Ice and Fire #4)', 17.21),
#  ('The Beast (Black Dagger Brotherhood #14)', 46.08),
#  ('Paper and Fire (The Great Library #2)', 49.45),
#  ('Harry Potter and the Order of the Phoenix (Harry Potter #5)', 31.63),
#  ('Harry Potter and the Half-Blood Prince (Harry Potter #6)', 48.75),
#  ('The Rose & the Dagger (The Wrath and the Dawn #2)', 58.64),
#  ('Heir to the Sky', 44.07),
#  ('Ash', 22.06),
#  ('Shadow Rites (Jane Yellowrock #10)', 21.72),
#  ('Myriad (Prentor #1)', 58.75),
#  ('The Hook Up (Game On #1)', 36.29),
#  ('Off Sides (Off #1)', 39.45),
#  ('Set Me Free', 17.46),
#  ('A Fierce and Subtle Poison', 28.13),
#  ('Scarlett Epstein Hates It Here', 43.55),
#  ('Library of Souls (Miss Peregrineâ\x80\x99s Peculiar Children #3)', 48.56),
#  ('Frostbite (Vampire Academy #2)', 29.99),
#  ('The Darkest Lie', 35.35),
#  ('Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   58.14),
#  ('The Epidemic (The Program 0.6)', 14.44),
#  ('No Love Allowed (Dodge Cove #1)', 54.65),
#  ('Exit, Pursued by a Bear', 51.34),
#  ('My Life Next Door (My Life Next Door )', 36.39),
#  ('Future Shock (Future Shock #1)', 55.65),
#  ('Nightstruck: A Novel', 50.35),
#  ('Will Grayson, Will Grayson (Will Grayson, Will Grayson)', 47.31),
#  ('Where She Went (If I Stay #2)', 41.73),
#  ('The Darkest Corners', 11.33),
#  ('Lola and the Boy Next Door (Anna and the French Kiss #2)', 23.63),
#  ('Kill the Boy Band', 15.52),
#  ('Isla and the Happily Ever After (Anna and the French Kiss #3)', 48.13),
#  ('An Abundance of Katherines', 10.0),
#  ('Harry Potter and the Prisoner of Azkaban (Harry Potter #3)', 24.17),
#  ('The Land of 10,000 Madonnas', 29.64),
#  ('Scarlet (The Lunar Chronicles #2)', 14.57),
#  ('Legend (Legend #1)', 43.69),
#  ('Lady Renegades (Rebel Belle #3)', 53.04),
#  ('Golden (Heart of Dread #3)', 42.21),
#  ('Annie on My Mind', 36.83),
#  ('New Moon (Twilight #2)', 12.86),
#  ('The Haters', 27.89),
#  ('The Art of Not Breathing', 40.83),
#  ("The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 42.96),
#  ('Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#   57.36),
#  ('Sorting the Beef from the Bull: The Science of Food Fraud Forensics',
#   44.74),
#  ('The Origin of Species', 10.01),
#  ('The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',
#   13.03),
#  ('The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements',
#   57.35),
#  ('Seven Brief Lessons on Physics', 30.6),
#  ("Shakespeare's Sonnets", 20.66),
#  ('Untitled Collection: Sabbath Poems 2014', 14.27),
#  ('Poems That Make Grown Women Cry', 14.19),
#  ('salt.', 46.78),
#  ('Quarter Life Poetry: Poems for the Young, Broke and Hangry', 50.89),
#  ('Out of Print: City Lights Spotlight No. 14', 53.64),
#  ('Les Fleurs du Mal', 29.04),
#  ('Leave This Song Behind: Teen Poetry at Its Best', 51.17),
#  ('The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#   15.42),
#  ('The Crossover', 38.77),
#  ('Booked', 17.49),
#  ('Twenty Love Poems and a Song of Despair', 30.95),
#  ('Wall and Piece', 44.18),
#  ('Art and Fear: Observations on the Perils (and Rewards) of Artmaking',
#   48.63),
#  ('History of Beauty', 10.29),
#  ('The Story of Art', 41.14),
#  ('Ways of Seeing', 39.51),
#  ('Approval Junkie: Adventures in Caring Too Much', 58.81),
#  ('Running with Scissors', 12.91),
#  ('Life Without a Recipe', 59.04),
#  ('A Heartbreaking Work of Staggering Genius', 54.29),
#  ('Fifty Shades Freed (Fifty Shades #3)', 15.36),
#  ('Old School (Diary of a Wimpy Kid #10)', 11.83),
#  ("I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#   25.98),
#  ('Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   14.75),
#  ('When You Are Engulfed in Flames', 30.89),
#  ("Lamb: The Gospel According to Biff, Christ's Childhood Pal", 55.5),
#  ('Psycho: Sanitarium (Psycho #1.5)', 36.97),
#  ('Dracula the Un-Dead', 35.63),
#  ('Night Shift (Night Shift #1-20)', 12.75),
#  ('Needful Things', 47.51),
#  ("'Salem's Lot", 49.56),
#  ('Sapiens: A Brief History of Humankind', 54.23),
#  ('"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#   44.48),
#  ('A Short History of Nearly Everything', 52.4),
#  ('Catherine the Great: Portrait of a Woman', 58.55),
#  ("The Mathews Men: Seven Brothers and the War Against Hitler's U-boats",
#   42.91),
#  ('The Hiding Place', 55.91),
#  ('Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   14.02),
#  ('The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 37.34),
#  ("Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   50.62),
#  ('Everyday Italian: 125 Simple and Delicious Recipes', 20.1),
#  ('The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   12.34),
#  ('Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   11.38),
#  ('How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#   46.01),
#  ('The Barefoot Contessa Cookbook', 59.92),
#  ('The Power Greens Cookbook: 140 Delicious Superfood Recipes', 11.05),
#  ('Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',
#   24.91),
#  ('Redeeming Love', 20.47),
#  ('Close to You', 49.46),
#  ('Shadows of the Past (Logan Point #1)', 39.67),
#  ('Counted With the Stars (Out from Egypt #1)', 17.97),
#  ('If I Run (If I Run #1)', 49.97),
#  ('The Dirty Little Secrets of Getting Your Dream Job', 33.34),
#  ('The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future', 12.61),
#  ('Made to Stick: Why Some Ideas Survive and Others Die', 38.85),
#  ('Born for This: How to Find the Work You Were Meant to Do', 21.59),
#  ('The Elephant Tree', 23.82),
#  ('Behind Closed Doors', 52.22),
#  ('You (You #1)', 43.61),
#  ('Killing Floor (Jack Reacher #1)', 31.49),
#  ('Someone Like You (The Harrisons #2)', 52.79),
#  ('The Four Agreements: A Practical Guide to Personal Freedom', 17.66),
#  ("The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   32.24),
#  ("A New Earth: Awakening to Your Life's Purpose", 55.65),
#  ('How to Stop Worrying and Start Living', 46.49),
#  ('All the Light We Cannot See', 29.87),
#  ('(Un)Qualified: How God Uses Broken People to Do Big Things', 54.0),
#  ('Suzie Snowflake: One beautiful flake (a self-esteem story)', 54.81),
#  ('10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', 49.71),
#  ('The Art and Science of Low Carbohydrate Living', 52.98),
#  ('Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   52.65),
#  ('Dark Notes', 19.19)]

# %% [markdown]
# ##### Comentario: Revela los libros con 4 estrellas o mas, los cuales definitivamente valen la pena leer

# %% [markdown]
# #### **Consulta 2: Libros que cuesten menos de 20 euros**

# %%
query2 = """
SELECT titulo, precio
FROM Libros
WHERE precio < 20
ORDER BY precio ASC;
"""
cursor.execute(query2)
cursor.fetchall()
# Out:
# [('An Abundance of Katherines', 10.0),
#  ('The Origin of Species', 10.01),
#  ('The Tipping Point: How Little Things Can Make a Big Difference', 10.02),
#  ('Patience', 10.16),
#  ('Greek Mythic History', 10.23),
#  ('The Fellowship of the Ring (The Lord of the Rings #1)', 10.27),
#  ('History of Beauty', 10.29),
#  ('The Lucifer Effect: Understanding How Good People Turn Evil', 10.4),
#  ('NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   10.41),
#  ('Pet Sematary', 10.56),
#  ('I Am Pilgrim (Pilgrim #1)', 10.6),
#  ('Counting Thyme', 10.62),
#  ('The Complete Maus (Maus #1-2)', 10.64),
#  ('The Project', 10.65),
#  ('Are We There Yet?', 10.66),
#  ('Tastes Like Fear (DI Marnie Rome #3)', 10.69),
#  ('Miss Peregrineâ\x80\x99s Home for Peculiar Children (Miss Peregrineâ\x80\x99s Peculiar Children #1)',
#   10.76),
#  ('Green Eggs and Ham (Beginner Books B-16)', 10.79),
#  ('A Clash of Kings (A Song of Ice and Fire #2)', 10.79),
#  ('Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection', 10.9),
#  ("The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)",
#   10.92),
#  ('The Argonauts', 10.93),
#  ('The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   10.97),
#  ('The Power Greens Cookbook: 140 Delicious Superfood Recipes', 11.05),
#  ('Reservations for Two', 11.1),
#  ('Beauty Restored (Riley Family Legacy Novellas #3)', 11.11),
#  ('Dear Mr. Knightley', 11.21),
#  ('City of Fallen Angels (The Mortal Instruments #4)', 11.23),
#  ('The Darkest Corners', 11.33),
#  ('Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   11.38),
#  ('Brilliant Beacons: A History of the American Lighthouse', 11.45),
#  ('Remember Me?', 11.48),
#  ('My Kitchen Year: 136 Recipes That Saved My Life', 11.53),
#  ('Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64),
#  ('The Sleep Revolution: Transforming Your Life, One Night at a Time', 11.68),
#  ('Saga, Volume 2 (Saga (Collected Editions) #2)', 11.75),
#  ('Underlying Notes', 11.82),
#  ('The 5th Wave (The 5th Wave #1)', 11.83),
#  ('Old School (Diary of a Wimpy Kid #10)', 11.83),
#  ('Hide Away (Eve Duncan #20)', 11.84),
#  ('Lust & Wonder', 11.87),
#  ('The Children', 11.88),
#  ('Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 11.89),
#  ('The Suffragettes (Little Black Classics, #96)', 11.89),
#  ('You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#   12.08),
#  ('Every Heart a Doorway (Every Heart A Doorway #1)', 12.16),
#  ("So You've Been Publicly Shamed", 12.23),
#  ('The Purest Hook (Second Circle Tattoos #3)', 12.25),
#  ('The Girl You Lost', 12.29),
#  ('The Giver (The Giver Quartet #1)', 12.3),
#  ('The Silent Wife', 12.34),
#  ('The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   12.34),
#  ('Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#   12.36),
#  ('Lila (Gilead #3)', 12.47),
#  ('Agnostic: A Spirited Manifesto', 12.51),
#  ('Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',
#   12.55),
#  ('The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future', 12.61),
#  ('Night Shift (Night Shift #1-20)', 12.75),
#  ('In Her Wake', 12.84),
#  ('New Moon (Twilight #2)', 12.86),
#  ('Dark Lover (Black Dagger Brotherhood #1)', 12.87),
#  ('Running with Scissors', 12.91),
#  ("Walt Disney's Alice in Wonderland", 12.96),
#  ('The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',
#   13.03),
#  ('Logan Kade (Fallen Crest High #5.5)', 13.12),
#  ('A Murder Over a Girl: Justice, Gender, Junior High', 13.2),
#  ('Life of Pi', 13.22),
#  ('The Three Searches, Meaning, and the Story', 13.33),
#  ('Sister Sable (The Mad Queen #1)', 13.33),
#  ('Mothering Sunday', 13.34),
#  ('Princess Between Worlds (Wide-Awake Princess #5)', 13.34),
#  ('Changing the Game (Play by Play #2)', 13.38),
#  ('Little Red', 13.47),
#  ('Night (The Night Trilogy #1)', 13.51),
#  ('Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   13.61),
#  ('Vegan Vegetarian Omnivore: Dinner for Everyone at the Table', 13.66),
#  ('Playing with Fire', 13.71),
#  ('Some Women', 13.73),
#  ('The Grand Design', 13.76),
#  ('The Guilty (Will Robie #4)', 13.82),
#  ("Will You Won't You Want Me?", 13.86),
#  ("Harry Potter and the Sorcerer's Stone (Harry Potter #1)", 13.9),
#  ('That Darkness (Gardiner and Renner #1)', 13.92),
#  ('Starving Hearts (Triangular Trade Trilogy, #1)', 13.99),
#  ('Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   14.02),
#  ('On a Midnight Clear', 14.07),
#  ('A Visit from the Goon Squad', 14.08),
#  ('Roller Girl', 14.1),
#  ('Outliers: The Story of Success', 14.16),
#  ('Poems That Make Grown Women Cry', 14.19),
#  ('Untitled Collection: Sabbath Poems 2014', 14.27),
#  ('Wild Swans', 14.36),
#  ('Eight Hundred Grapes', 14.39),
#  ('The End of the Jesus Era (An Investigation #1)', 14.4),
#  ('The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)',
#   14.41),
#  ('The Epidemic (The Program 0.6)', 14.44),
#  ('The Guns of August', 14.54),
#  ('Scarlet (The Lunar Chronicles #2)', 14.57),
#  ('A Distant Mirror: The Calamitous 14th Century', 14.58),
#  ('Two Summers', 14.64),
#  ('Harry Potter and the Chamber of Secrets (Harry Potter #2)', 14.74),
#  ("A Gentleman's Position (Society of Gentlemen #3)", 14.75),
#  ('Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   14.75),
#  ('The Communist Manifesto', 14.76),
#  ('The Hound of the Baskervilles (Sherlock Holmes #5)', 14.82),
#  ('Obsidian (Lux #1)', 14.86),
#  ('Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   15.06),
#  ('The Secret Garden', 15.08),
#  ('Disrupted: My Misadventure in the Start-Up Bubble', 15.28),
#  ('Fifty Shades Freed (Fifty Shades #3)', 15.36),
#  ('Batman: The Dark Knight Returns (Batman)', 15.38),
#  ('Vampire Knight, Vol. 1 (Vampire Knight #1)', 15.4),
#  ('The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#   15.42),
#  ('Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 15.44),
#  ("Ayumi's Violin", 15.48),
#  ('Kill the Boy Band', 15.52),
#  ('One with You (Crossfire #5)', 15.71),
#  ('The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâ\x80\x99s Most Precious Manuscripts',
#   15.77),
#  ('The Travelers', 15.77),
#  ('The Girl You Left Behind (The Girl You Left Behind #1)', 15.79),
#  ('The Girl In The Ice (DCI Erika Foster #1)', 15.85),
#  ("Sophie's World", 15.94),
#  ('First and First (Five Boroughs #3)', 15.97),
#  ('The Iliad', 16.16),
#  ('Shiver (The Wolves of Mercy Falls #1)', 16.23),
#  ('Something More Than This', 16.24),
#  ('The Glass Castle', 16.24),
#  ('The Cat in the Hat (Beginner Books B-1)', 16.26),
#  ('Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 16.28),
#  ('Lady Midnight (The Dark Artifices #1)', 16.28),
#  ('Peak: Secrets from the New Science of Expertise', 16.28),
#  ('Fruits Basket, Vol. 5 (Fruits Basket #5)', 16.33),
#  ('Daredevils', 16.34),
#  ('The Constant Princess (The Tudor Court #1)', 16.62),
#  ('A Murder in Time', 16.64),
#  ('The Flowers Lied', 16.68),
#  ('A Study in Scarlet (Sherlock Holmes #1)', 16.73),
#  ('The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   16.77),
#  ('The Course of Love', 16.78),
#  ('The Gunning of America: Business and the Making of American Gun Culture',
#   16.81),
#  ('Louisa: The Extraordinary Life of Mrs. Adams', 16.85),
#  ('The Power of Habit: Why We Do What We Do in Life and Business', 16.88),
#  ('Mother, Can You Not?', 16.89),
#  ('Fool Me Once', 16.96),
#  ("A Spy's Devotion (The Regency Spies of London #1)", 16.97),
#  ('Balloon Animals', 17.03),
#  ('Camp Midnight', 17.08),
#  ('A Feast for Crows (A Song of Ice and Fire #4)', 17.21),
#  ('The Genius of Birds', 17.24),
#  ('Thirst', 17.27),
#  ('Lilac Girls', 17.28),
#  ('The Literature Book (Big Ideas Simply Explained)', 17.43),
#  ('The Stranger', 17.44),
#  ('Set Me Free', 17.46),
#  ('Booked', 17.49),
#  ('The Four Agreements: A Practical Guide to Personal Freedom', 17.66),
#  ('Wuthering Heights', 17.73),
#  ('Why Not Me?', 17.76),
#  ('The Hobbit (Middle-Earth Universe)', 17.8),
#  ('David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#   17.81),
#  ('The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   17.93),
#  ('Counted With the Stars (Out from Egypt #1)', 17.97),
#  ('Maude (1883-1993):She Grew Up with the country', 18.02),
#  ('Love Is a Mix Tape (Music #1)', 18.03),
#  ("Where'd You Go, Bernadette", 18.13),
#  ('Once Was a Time', 18.28),
#  ('Give It Back', 18.32),
#  ('Amy Meets the Saints and Sages', 18.46),
#  ('Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', 18.51),
#  ('Eclipse (Twilight #3)', 18.74),
#  ('The Golden Compass (His Dark Materials #1)', 18.77),
#  ('Unicorn Tracks', 18.78),
#  ('Taking Shots (Assassins #1)', 18.88),
#  ('Pop Gun War, Volume 1: Gift', 18.97),
#  ('Me Before You (Me Before You #1)', 19.02),
#  ('Ready Player One', 19.07),
#  ('The Torch Is Passed: A Harding Family Story', 19.09),
#  ('Large Print Heart of the Pride', 19.15),
#  ('The Edge of Reason (Bridget Jones #2)', 19.18),
#  ('Dark Notes', 19.19),
#  ("The Cuckoo's Calling (Cormoran Strike #1)", 19.21),
#  ("Brazen: The Courage to Find the You That's Been Hiding", 19.22),
#  ('Pride and Prejudice', 19.27),
#  ('Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   19.43),
#  ('This One Summer', 19.49),
#  ("A Mother's Reckoning: Living in the Aftermath of Tragedy", 19.53),
#  ("It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#   19.55),
#  ('Fruits Basket, Vol. 7 (Fruits Basket #7)', 19.57),
#  ("What's It Like in Space?: Stories from Astronauts Who've Been There", 19.6),
#  ('In a Dark, Dark Wood', 19.63),
#  ('Outlander (Outlander #1)', 19.67),
#  ("I've Got Your Number", 19.69),
#  ('The Zombie Room', 19.69),
#  ('The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   19.73),
#  ('Reskilling America: Learning to Labor in the Twenty-First Century', 19.83),
#  ('Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 19.92)]

# %% [markdown]
# ##### Comentario: Gran variedad de libros para un presupuesto ajustado

# %% [markdown]
# #### **Consulta 3: Los 5 libros mas baratos**

# %%
query3 = """
SELECT titulo, categoria, precio
FROM Libros
ORDER BY precio ASC
LIMIT 5;
"""
cursor.execute(query3)
cursor.fetchall()
# Out:
# [('An Abundance of Katherines', 'Young Adult', 10.0),
#  ('The Origin of Species', 'Science', 10.01),
#  ('The Tipping Point: How Little Things Can Make a Big Difference',
#   'Add a comment',
#   10.02),
#  ('Patience', 'Sequential Art', 10.16),
#  ('Greek Mythic History', 'Default', 10.23)]

# %% [markdown]
# ##### Comentario: top 5 definitivo para el ahorrador

# %% [markdown]
# #### **Consulta 4: Libros que cuestan mas de 20, pero tienen rating de 2 o menos estrellas**

# %%
query4 = """
SELECT titulo, precio, rating
FROM Libros
WHERE precio >20 and rating <=2
ORDER BY precio DESC
LIMIT 5;
"""
cursor.execute(query4)
cursor.fetchall()
# Out:
# [('Civilization and Its Discontents', 59.95, 2),
#  ('Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#   59.64,
#   1),
#  ('The Improbability of Love', 59.45, 1),
#  ("Miller's Valley", 58.54, 2),
#  ("The Lover's Dictionary", 58.09, 2)]

# %% [markdown]
# ##### Comentario: Libros que ademas de ser caros, probablemente son malos (y queremos evitar)

# %% [markdown]
# #### **Consulta 5: Categorias con mas libros**

# %%
cursor.execute("""
SELECT categoria, COUNT(id) AS cantidad
FROM Libros
GROUP BY categoria
ORDER BY cantidad DESC
LIMIT 5;
""")
cursor.fetchall()
# Out:
# [('Default', 152),
#  ('Nonfiction', 110),
#  ('Sequential Art', 75),
#  ('Add a comment', 67),
#  ('Fiction', 65)]

# %% [markdown]
# ##### Comentario: Donde los escritores publican más rápido de lo que podés leer.

# %% [markdown]
# #### **Consulta sin indice vs consulta con indice**

# %%
query = """
SELECT titulo, precio, rating
FROM Libros
WHERE precio < 25 AND rating >= 3
ORDER BY precio ASC;
"""

cursor.execute(query)
cursor.fetchall()
#probamos consultar libros con precio menor a 25 y rating mayor o igual a 3 estrellas
# Out:
# [('An Abundance of Katherines', 10.0, 5),
#  ('The Origin of Species', 10.01, 4),
#  ('Patience', 10.16, 3),
#  ('Greek Mythic History', 10.23, 5),
#  ('History of Beauty', 10.29, 4),
#  ('NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   10.41,
#   4),
#  ('Pet Sematary', 10.56, 3),
#  ('I Am Pilgrim (Pilgrim #1)', 10.6, 4),
#  ('The Complete Maus (Maus #1-2)', 10.64, 3),
#  ('Are We There Yet?', 10.66, 3),
#  ('Green Eggs and Ham (Beginner Books B-16)', 10.79, 4),
#  ('A Clash of Kings (A Song of Ice and Fire #2)', 10.79, 3),
#  ('The Power Greens Cookbook: 140 Delicious Superfood Recipes', 11.05, 5),
#  ('Reservations for Two', 11.1, 3),
#  ('Dear Mr. Knightley', 11.21, 5),
#  ('City of Fallen Angels (The Mortal Instruments #4)', 11.23, 4),
#  ('The Darkest Corners', 11.33, 5),
#  ('Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   11.38,
#   5),
#  ('Brilliant Beacons: A History of the American Lighthouse', 11.45, 3),
#  ('Remember Me?', 11.48, 3),
#  ('Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64, 5),
#  ('The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   11.68,
#   4),
#  ('Saga, Volume 2 (Saga (Collected Editions) #2)', 11.75, 3),
#  ('Old School (Diary of a Wimpy Kid #10)', 11.83, 5),
#  ('The Children', 11.88, 3),
#  ('Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', 11.89, 5),
#  ('You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#   12.08,
#   3),
#  ('Every Heart a Doorway (Every Heart A Doorway #1)', 12.16, 5),
#  ('The Girl You Lost', 12.29, 5),
#  ('The Silent Wife', 12.34, 5),
#  ('The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   12.34,
#   4),
#  ('Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#   12.36,
#   3),
#  ('Lila (Gilead #3)', 12.47, 3),
#  ('Agnostic: A Spirited Manifesto', 12.51, 5),
#  ('Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',
#   12.55,
#   3),
#  ('The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future', 12.61, 5),
#  ('Night Shift (Night Shift #1-20)', 12.75, 4),
#  ('New Moon (Twilight #2)', 12.86, 4),
#  ('Running with Scissors', 12.91, 4),
#  ("Walt Disney's Alice in Wonderland", 12.96, 5),
#  ('The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',
#   13.03,
#   4),
#  ('A Murder Over a Girl: Justice, Gender, Junior High', 13.2, 3),
#  ('Life of Pi', 13.22, 4),
#  ('The Three Searches, Meaning, and the Story', 13.33, 3),
#  ('Sister Sable (The Mad Queen #1)', 13.33, 3),
#  ('Princess Between Worlds (Wide-Awake Princess #5)', 13.34, 5),
#  ('Changing the Game (Play by Play #2)', 13.38, 3),
#  ('Little Red', 13.47, 3),
#  ('Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   13.61,
#   5),
#  ('Playing with Fire', 13.71, 3),
#  ('Some Women', 13.73, 5),
#  ('The Grand Design', 13.76, 3),
#  ("Will You Won't You Want Me?", 13.86, 3),
#  ("Harry Potter and the Sorcerer's Stone (Harry Potter #1)", 13.9, 3),
#  ('Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   14.02,
#   4),
#  ('On a Midnight Clear', 14.07, 3),
#  ('A Visit from the Goon Squad', 14.08, 5),
#  ('Roller Girl', 14.1, 5),
#  ('Poems That Make Grown Women Cry', 14.19, 4),
#  ('Untitled Collection: Sabbath Poems 2014', 14.27, 4),
#  ('Eight Hundred Grapes', 14.39, 4),
#  ('The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)',
#   14.41,
#   3),
#  ('The Epidemic (The Program 0.6)', 14.44, 5),
#  ('Scarlet (The Lunar Chronicles #2)', 14.57, 4),
#  ('A Distant Mirror: The Calamitous 14th Century', 14.58, 3),
#  ("A Gentleman's Position (Society of Gentlemen #3)", 14.75, 5),
#  ('Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   14.75,
#   5),
#  ('The Communist Manifesto', 14.76, 3),
#  ('Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   15.06,
#   4),
#  ('The Secret Garden', 15.08, 4),
#  ('Disrupted: My Misadventure in the Start-Up Bubble', 15.28, 5),
#  ('Fifty Shades Freed (Fifty Shades #3)', 15.36, 5),
#  ('Batman: The Dark Knight Returns (Batman)', 15.38, 5),
#  ('The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#   15.42,
#   5),
#  ('Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 15.44, 4),
#  ('Kill the Boy Band', 15.52, 5),
#  ('One with You (Crossfire #5)', 15.71, 4),
#  ('The Girl In The Ice (DCI Erika Foster #1)', 15.85, 3),
#  ("Sophie's World", 15.94, 5),
#  ('First and First (Five Boroughs #3)', 15.97, 4),
#  ('Shiver (The Wolves of Mercy Falls #1)', 16.23, 5),
#  ('Something More Than This', 16.24, 4),
#  ('Lady Midnight (The Dark Artifices #1)', 16.28, 5),
#  ('Daredevils', 16.34, 3),
#  ('The Constant Princess (The Tudor Court #1)', 16.62, 3),
#  ('The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   16.77,
#   3),
#  ('The Course of Love', 16.78, 3),
#  ('The Gunning of America: Business and the Making of American Gun Culture',
#   16.81,
#   4),
#  ('The Power of Habit: Why We Do What We Do in Life and Business', 16.88, 3),
#  ('Mother, Can You Not?', 16.89, 5),
#  ("A Spy's Devotion (The Regency Spies of London #1)", 16.97, 5),
#  ('Balloon Animals', 17.03, 3),
#  ('Camp Midnight', 17.08, 4),
#  ('A Feast for Crows (A Song of Ice and Fire #4)', 17.21, 4),
#  ('Thirst', 17.27, 5),
#  ('The Literature Book (Big Ideas Simply Explained)', 17.43, 3),
#  ('The Stranger', 17.44, 4),
#  ('Set Me Free', 17.46, 5),
#  ('Booked', 17.49, 5),
#  ('The Four Agreements: A Practical Guide to Personal Freedom', 17.66, 5),
#  ('Wuthering Heights', 17.73, 3),
#  ('The Hobbit (Middle-Earth Universe)', 17.8, 5),
#  ('The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   17.93,
#   3),
#  ('Counted With the Stars (Out from Egypt #1)', 17.97, 5),
#  ('Amy Meets the Saints and Sages', 18.46, 3),
#  ('Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', 18.51, 4),
#  ('Unicorn Tracks', 18.78, 3),
#  ('Ready Player One', 19.07, 4),
#  ('The Edge of Reason (Bridget Jones #2)', 19.18, 4),
#  ('Dark Notes', 19.19, 5),
#  ('Pride and Prejudice', 19.27, 4),
#  ('Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   19.43,
#   3),
#  ('This One Summer', 19.49, 4),
#  ("A Mother's Reckoning: Living in the Aftermath of Tragedy", 19.53, 3),
#  ('Outlander (Outlander #1)', 19.67, 5),
#  ('The Zombie Room', 19.69, 5),
#  ('No One Here Gets Out Alive', 20.02, 5),
#  ('Everyday Italian: 125 Simple and Delicious Recipes', 20.1, 5),
#  ('Is Everyone Hanging Out Without Me? (And Other Concerns)', 20.11, 3),
#  ('Team of Rivals: The Political Genius of Abraham Lincoln', 20.12, 5),
#  ('John Vassos: Industrial Design for Modern Life', 20.22, 4),
#  ('Cell', 20.29, 4),
#  ('Blood Defense (Samantha Brinkman #1)', 20.3, 3),
#  ('Mockingjay (The Hunger Games #3)', 20.44, 4),
#  ('Keep Me Posted', 20.46, 4),
#  ('Redeeming Love', 20.47, 5),
#  ('Cravings: Recipes for What You Want to Eat', 20.5, 3),
#  ('The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   20.59,
#   5),
#  ("Shakespeare's Sonnets", 20.66, 4),
#  ('Between Shades of Gray', 20.79, 5),
#  ('Adultery', 20.88, 5),
#  ('Delivering the Truth (Quaker Midwife Mystery #1)', 20.89, 4),
#  ('Sit, Stay, Love', 20.9, 3),
#  ('Fruits Basket, Vol. 6 (Fruits Basket #6)', 20.96, 4),
#  ('The Art of Startup Fundraising', 21.0, 3),
#  ('Voyager (Outlander #3)', 21.07, 5),
#  ('Boy Meets Boy', 21.12, 3),
#  ('Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   21.21,
#   3),
#  ('Fire Bound (Sea Haven/Sisters of the Heart #5)', 21.28, 4),
#  ('An Unquiet Mind: A Memoir of Moods and Madness', 21.3, 3),
#  ('Arena', 21.36, 4),
#  ('Beautiful Creatures (Caster Chronicles #1)', 21.55, 5),
#  ('Saga, Volume 3 (Saga (Collected Editions) #3)', 21.57, 5),
#  ('Born for This: How to Find the Work You Were Meant to Do', 21.59, 5),
#  ('Paper Girls, Vol. 1 (Paper Girls #1-5)', 21.71, 4),
#  ('Shadow Rites (Jane Yellowrock #10)', 21.72, 4),
#  ('Blink: The Power of Thinking Without Thinking', 21.74, 5),
#  ('1491: New Revelations of the Americas Before Columbus', 21.8, 3),
#  ('Rising Strong', 21.82, 3),
#  ('You Are What You Love: The Spiritual Power of Habit', 21.87, 4),
#  ('Hystopia: A Novel', 21.96, 4),
#  ('In the Country We Love: My Family Divided', 22.0, 4),
#  ('Ash', 22.06, 4),
#  ('Code Name Verity (Code Name Verity #1)', 22.13, 4),
#  ('The End of Faith: Religion, Terror, and the Future of Reason', 22.13, 4),
#  ("America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   22.5,
#   3),
#  ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   22.6,
#   4),
#  ('Charlie and the Chocolate Factory (Charlie Bucket #1)', 22.85, 3),
#  ('The Silkworm (Cormoran Strike #2)', 23.05, 5),
#  ('#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   23.11,
#   5),
#  ('Three-Martini Lunch', 23.21, 3),
#  ('Red Dragon (Hannibal Lecter #1)', 23.37, 3),
#  ('Rain Fish', 23.57, 3),
#  ('Lola and the Boy Next Door (Anna and the French Kiss #2)', 23.63, 4),
#  ('The Elephant Tree', 23.82, 5),
#  ('The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   23.89,
#   4),
#  ('Dark Places', 23.9, 5),
#  ('Harry Potter and the Prisoner of Azkaban (Harry Potter #3)', 24.17, 4),
#  ('My Mrs. Brown', 24.48, 3),
#  ('The Book of Mormon', 24.57, 3),
#  ('Zealot: The Life and Times of Jesus of Nazareth', 24.7, 3),
#  ('The Little Paris Bookshop', 24.73, 3),
#  ('The Mysterious Affair at Styles (Hercule Poirot #1)', 24.8, 4),
#  ('Lord of the Flies', 24.89, 3),
#  ('Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',
#   24.91,
#   5)]

# %%
import time

def medir_tiempo(query, repeticiones=5): #lo ejecutamos 5 veces, para obtener un promedio
    tiempos = []
    for _ in range(repeticiones):
        inicio = time.time() #registra el momento justo antes de ejecutar la consulta
        cursor.execute(query)
        cursor.fetchall()
        tiempos.append(time.time() - inicio)
    return sum(tiempos) / len(tiempos)

tiempo_sin_indice = medir_tiempo(query)
print("⏱️ Promedio SIN índice:", round(tiempo_sin_indice, 6), "segundos")
# Out:
# ⏱️ Promedio SIN índice: 0.001138 segundos

# %%
cursor.execute("CREATE INDEX IF NOT EXISTS idx_libros_precio ON Libros(precio);") #creamos indice
conn.commit()

# %%
tiempo_con_indice = medir_tiempo(query) #volvemos a medir despues de los cambios
print("⚡ Promedio CON índice:", round(tiempo_con_indice, 6), "segundos")
# Out:
# ⚡ Promedio CON índice: 0.000594 segundos

# %%
print(f"🔍 Diferencia: {round(tiempo_sin_indice - tiempo_con_indice, 6)} segundos")
# Out:
# 🔍 Diferencia: 0.000544 segundos

# %% [markdown]
# **Análisis del efecto del índice**:
# La consulta selecciona libros con precio menor a £25 y rating mayor o igual a 3.
# Sin índice, la base recorre todas las filas para evaluar la condición (precio < 25).
# Luego de crear el índice en la columna precio, SQLite puede acceder directamente a las filas relevantes,
# reduciendo el tiempo de búsqueda.
# En este dataset pequeño la diferencia es mínima, pero en bases reales con miles de registros la mejora
# sería significativa, pasando de segundos a milisegundos.
